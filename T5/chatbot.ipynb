# %% [markdown]
# ## **Generation Chatbot with T5**

# %%
# !pip install transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 43.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 108.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.9 MB/s eta 0:00:00

# %% [markdown]
# ### **Load model from huggingface**

# %%
from transformers import T5ForConditionalGeneration, T5TokenizerFast

MODEL_NAME = "danfarh2000/t5-base-end2end-chatbot-generative"
chatbot_model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME)
tokenizer = T5TokenizerFast.from_pretrained(MODEL_NAME)

# %%
def run_model(input_string, **generator_args):
  generator_args = {
  "max_length": 256,
  "num_beams": 4,
  "length_penalty": 1.5,
  "no_repeat_ngram_size": 3,
  "early_stopping": True,
  }
  input_string = input_string
  input_ids = tokenizer.encode(input_string, return_tensors="pt")
  res = chatbot_model.generate(input_ids, **generator_args)
  output = tokenizer.batch_decode(res, skip_special_tokens=True)[0]
  x = slice(9, -7)
  return output[x]

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
while True:
  question = input("User: ")
  if question == 'exit':
    break
  else:
    print(color.BOLD + 'Bot: ' + color.END, run_model(question))
# Out:
# User: hey
# Bot:  hey i'm a newbie
# User: how are you doing?
# Bot:  i'm doing well
# User: what do you do in your free time?
# Bot:  reading
# User: Do you like to play football too?
# Bot:  yes
# User: what do you like to do anymore?
# Bot:  i'm a tv personality and i like to watch movies
# User: great, I like watching movies too
# Bot:  i'm a big fan of movies i like watching them too
# User: Do you enjoy listening to music?
# Bot:  i do a lot of listening to music
# User: who is your favorite singer?
# Bot:  i'm not a singer but i love a lot of the songs i like
# User: I enjoyed talking with you
# Bot:  thank you
# User: bye
# Bot:  bye
# User: exit

# %%
while True:
  question = input("User: ")
  if question == 'exit':
    break
  else:
    print(color.BOLD + 'Bot: ' + color.END, run_model(question))
# Out:
# User: hello
# Bot:  hello i'm a newbie
# User: I want to buy a mobile phone, what brand do you recommend me?
# Bot:  i'm looking for a new phone and i haven't heard of it yet
# User: great, do recommend me apple brand?
# Bot:  i've never heard of apple but it's a great brand
# User: what about another brands?
# Bot:  i've never heard of them but i haven't tried them yet
# User: Do you recommend me A51 mobile phone?
# Bot:  i don't know if it's a good phone but i've heard good things about it
# User: How about A71, Is that better than A51?
# Bot:  i'm not sure if it's better than A71
# User: ok thank you
# Bot:  thank you
# User: bye
# Bot:  bye
# User: exit

# %%
while True:
  question = input("User: ")
  if question == 'exit':
    break
  else:
    print(color.BOLD + 'Bot: ' + color.END, run_model(question))
# Out:
# User: hey
# Bot:  hey i'm a newbie
# User: how are you doing?
# Bot:  i'm doing well
# User: I want to learn about python and django, can you help me?
# Bot:  python and django are two of my favorite programming languages
# User: give me some information about decorators in python
# Bot:  i'm not a python fan but i love it
# User: please give me some information about django rest framework
# Bot:  django rest framework
# User: please explain me about abstract class
# Bot:  what is abstract class
# User: It is related to object oriented programming
# Bot:  what is object oriented programming
# User: I think you don't train on programming data
# Bot:  i don't train on programming but i'm pretty good at it
# User: ok thanks
# Bot:  thank you
# User: exit

# %%
while True:
  question = input("User: ")
  if question == 'exit':
    break
  else:
    print(color.BOLD + 'Bot: ' + color.END, run_model(question))
# Out:
# User: hey
# Bot:  hey i'm a newbie
# User: how are you doing?
# Bot:  i'm doing well
# User: Are you a football fan?
# Bot:  i'm a football fan
# User: which team do you fan?
# Bot:  i'm a big fan of the nfl but i don't know if it's a team
# User: Do you know Leo Messi?
# Bot:  yes
# User: Can you give me some information about Messi?
# Bot:  i've never heard of him but he's a great guy
# User: Do you know Ronaldo?
# Bot:  Ronaldo
# User: exit

# %%
while True:
  question = input("User: ")
  if question == 'exit':
    break
  else:
    print(color.BOLD + 'Bot: ' + color.END, run_model(question))
# Out:
# User: hey, how are you?
# Bot:  hey i'm doing well
# User: I have diabetes, could you pleasee give me some advice?
# Bot:  i don't know if i'm a diabetic
# User: what is diabetes?
# Bot:  i don't have diabetes but i'm a diabetic
# User: Tell me about diabetes type one and two
# Bot:  i don't know what type of diabetes i have but i'm not sure if it's type 2 or not
# User: exit
